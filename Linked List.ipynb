# %% [markdown]
# # Singly Linked List

# %% [markdown]
# ### Creation

# %%
# creating a node

Class Node:
    def __init__(self,data):
        self.data = data;
        self.reference = None;
    node1 = Node(7)      # node1 will got o self and 7 will go to data
    print(node1.data)
    print(node1.reference)
    
class LinketList:
    def __init__(self)
    self.head = None

# %%
# creating a singly linked list

class Node:
    def __init__(self,data):
        self.data = data
        self.reference = None
        
class SinglyLL:
    def __init__(self):
        self.head = None
        print("Ankur")

sll = SinglyLL()    #sll.head=None
# Out:
# Ankur

# %%
# Traversal in Linked List

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
# Out:
# 20 25 30 35

# %%
# Insertion at Beginning

# Traversal in Linked List

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        print()
        nb = Node(data)
        nb.next = self.head
        self.head = nb


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
# Out:
# 20 25 30 35

# %%
# Insertion at end

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head = nb
    
    def insert_at_end(self,data):
        print()
        ne = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next
        a.next = ne
        


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
sll.traversal()
sll.insert_at_end(25)
sll.traversal()
# Out:
# 20 25 30 35 2 20 25 30 35
# 2 20 25 30 35 25

# %%
# Insertion at specified Node

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head = nb
    
    def insert_at_end(self,data):
        print()
        ne = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next            
        a.next = ne
    
    def insert_at_specified_location(self,position,data):
        print()
        nib = Node(data)
        a = self.head
        for i in range(1,position-1):
            a = a.next
        nib.next = a.next
        a.next = nib


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
sll.traversal()
sll.insert_at_end(25)
sll.traversal()
sll.insert_at_specified_location(3,727)
sll.traversal()
# Out:
# 20 25 30 35 2 20 25 30 35
# 2 20 25 30 35 25
# 2 20 727 25 30 35 25

# %% [markdown]
# ### Deletion

# %%
# Deletion at beginning

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head = nb
    
    def insert_at_end(self,data):
        print()
        ne = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next            
        a.next = ne
    
    def insert_at_specified_location(self,position,data):
        print()
        nib = Node(data)
        a = self.head
        for i in range(1,position-1):
            a = a.next
        nib.next = a.next
        a.next = nib
        
    def deletion_at_beginning(self):
        print()
        a = self.head
        self.head = a.next
        a.next = None
    


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
sll.traversal()
sll.insert_at_end(25)
sll.traversal()
sll.insert_at_specified_location(3,727)
sll.traversal()
sll.deletion_at_beginning()
sll.traversal()
# Out:
# 20 25 30 35 2 20 25 30 35
# 2 20 25 30 35 25
# 2 20 727 25 30 35 25
# 20 727 25 30 35 25

# %%
# Deletion at end

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head = nb
    
    def insert_at_end(self,data):
        print()
        ne = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next            
        a.next = ne
    
    def insert_at_specified_location(self,position,data):
        print()
        nib = Node(data)
        a = self.head
        for i in range(1,position-1):
            a = a.next
        nib.next = a.next
        a.next = nib
        
    def deletion_at_beginning(self):
        print()
        a = self.head
        self.head = a.next
        a.next = None
        
    def deletion_at_end(self):
        print()
        prev = self.head
        a = self.head.next
        while a.next is not None:
            a = a.next
            prev = prev.next
        prev.next = None
    


n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
sll.traversal()
sll.insert_at_end(25)
sll.traversal()
sll.insert_at_specified_location(3,727)
sll.traversal()
sll.deletion_at_beginning()
sll.traversal()
sll.deletion_at_end()
sll.traversal()
# Out:
# 20 25 30 35 2 20 25 30 35
# 2 20 25 30 35 25
# 2 20 727 25 30 35 25
# 20 727 25 30 35 25
# 20 727 25 30 35

# %%
# Deletion at specified position

class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class Sll:
    def __init__(self):
        self.head = None
    
    def traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def insert_at_beginning(self,data):
        nb = Node(data)
        nb.next = self.head
        self.head = nb
    
    def insert_at_end(self,data):
        print()
        ne = Node(data)
        a = self.head
        while a.next is not None:
            a = a.next            
        a.next = ne
    
    def insert_at_specified_location(self,position,data):
        print()
        nib = Node(data)
        a = self.head
        for i in range(1,position-1):
            a = a.next
        nib.next = a.next
        a.next = nib
        
    def deletion_at_beginning(self):
        print()
        a = self.head
        self.head = a.next
        a.next = None
        
    def deletion_at_end(self):
        print()
        prev = self.head
        a = self.head.next
        while a.next is not None:
            a = a.next
            prev = prev.next
        prev.next = None
    
    def deletion_at_particular_position(self,position):
        print()
        prev = self.head
        a = self.head.next
        for i in range(1,position-1):
            a = a.next
            prev = prev.next
        prev.next = a.next
        a.next = None
            
        
n1 = Node(20)

sll = Sll()
sll.head = n1

n2 = Node(25)
n1.next = n2
n3 = Node(30)
n2.next = n3
n4 = Node(35)
n3.next = n4

sll.traversal()
sll.insert_at_beginning(2)
sll.traversal()
sll.insert_at_end(25)
sll.traversal()
sll.insert_at_specified_location(3,727)
sll.traversal()
sll.deletion_at_beginning()
sll.traversal()
sll.deletion_at_end()
sll.traversal()
sll.deletion_at_particular_position(3)
sll.traversal()
# Out:
# 20 25 30 35 2 20 25 30 35
# 2 20 25 30 35 25
# 2 20 727 25 30 35 25
# 20 727 25 30 35 25
# 20 727 25 30 35
# 20 727 30 35

# %% [markdown]
# # Doubly Linked List

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        self.previous = None

class Sll:
    def __init__(self):
        self.head = None
    
    def forward_traversal(self):
        if self.head is None:
            print("Doubly List is Empty")
        else:
            a = self.head
            while a is not None:
                print(a.data, end=" ")
                a = a.next
    
    def backward_traversal(self):
        if self.head is None:
            print("Singly List is Empty")
        else:
            a = self.head
            while a.next is not None:
                a = a.next
                
            while a is not None:
                print(a.data, end=" ")
                a = a.next

n1 = Node(20)

dll = Dll()
dll.head = n1

n2 = Node(25)
n2.prev = n1
n1.next = n2
n3 = Node(30)
n3.prev = n2
n2.next = n3
n4 = Node(35)
n3.next = n4
n4.prev = n3

dll.forward_traversal()
dll.backward_traversal()



# 3:25:00 time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 34>()
#      30                 a = a.next
#      32 n1 = Node(20)
# ---> 34 dll = Dll()
#      35 dll.head = n1
#      37 n2 = Node(25)
#
# NameError: name 'Dll' is not defined
